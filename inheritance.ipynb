# %% [markdown]
# #### single inheritance

# %%
class parent:
    def show(self):
        print("parent")
class child(parent):
    def display(self):
        print("child")
obj = child()
obj.show()
obj.display()
# Out:
# parent
# child

# %% [markdown]
# ### multipleinheritance

# %%
class father:
    def show1(self):
        print("father")
class mother:
    def show2(self):
        print("mother")
class child(father,mother):
    def show3(self):
        print("child")
obj = child()
obj.show1()
obj.show2()
obj.show3()
# Out:
# father
# mother
# child

# %% [markdown]
# ### Multilevel Inheritance

# %%
class grandparent:
    def method1(self):
        print("grandparent")
class father(grandparent):
    def method2(self):
        print("father")
class son(father):
    def method3(self):
        print("son")
obj = son()
obj.method1()
obj.method2()
obj.method3()
# Out:
# grandparent
# father
# son

# %% [markdown]
# ### Hierarchical Inheritance

# %%
class father:
    def show1(self):
        print("father")
class child1(father):
    def show2(self):
        print("child1")
class child2(father):
    def show3(self):
        print("child2")
obj1 = child1()
obj2 = child2()
obj1.show1()
obj1.show2()
obj2.show3()
# Out:
# father
# child1
# child2

# %% [markdown]
# hybrid inheritance

# %%
class A:
    def methodA(self):
        print("Class A")

class B(A):
    def methodB(self):
        print("Class B")

class C(A):
    def methodC(self):
        print("Class C")

class D(B, C):
    def methodD(self):
        print("Class D")

obj = D()
obj.methodA()
obj.methodB()
obj.methodC()
obj.methodD()
# Out:
# Class A
# Class B
# Class C
# Class D
